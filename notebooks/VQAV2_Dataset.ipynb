# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmood-Anaam/Arabic-VQA/blob/main/notebooks/VQAV2_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # View Dataset
#
# This notebook explores the OK-VQA Arabic-English dataset.  You can find the dataset on Hugging Face: [Ok-vqa-ar-en](https://huggingface.co/datasets/MahmoodAnaam/ok-vqa-ar-en/tree/main)

# %%
# Clone the Arabic-VQA repository from GitHub.
# !git clone https://github.com/Mahmood-Anaam/Arabic-VQA.git
# Out:
# Cloning into 'Arabic-VQA'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 36 (delta 8), reused 24 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 3.86 MiB | 31.85 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# Install the required libraries from the requirements.txt file.
# !pip install -r /content/Arabic-VQA/requirements.txt --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# Login to Hugging Face
from huggingface_hub import login
from google.colab import userdata

huggingface_token = userdata.get('huggingface_token')
login(token=huggingface_token)

# %%
# Load the dataset.
from datasets import load_dataset

dataset = load_dataset("MahmoodAnaam/ok-vqa-ar-en", split="validation")
# Print some information about the dataset.
dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# ok-vqa-ar-en.py:   0%|          | 0.00/5.98k [00:00<?, ?B/s]
# The repository for MahmoodAnaam/ok-vqa-ar-en contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/MahmoodAnaam/ok-vqa-ar-en.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# ...

# %%
dataset[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>,
#  'question_type': 'one',
#  'confidence': 3,
#  'answers': [{'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 1},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 2},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 3},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 4},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 5},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 6},
#   {'answer': 'motocross',
#    'raw_answer': 'motocross',
#    'answer_confidence': 'yes',
#    'answer_id': 7},
#   {'answer': 'motocross',
#    'raw_answer': 'motocross',
#    'answer_confidence': 'yes',
# ...
