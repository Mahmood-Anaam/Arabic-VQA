# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmood-Anaam/Arabic-VQA/blob/main/notebooks/OK_VQA_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook explores the OK-VQA Arabic-English dataset.  You can find the dataset on Hugging Face: [ok-vqa-ar-en](https://huggingface.co/datasets/MahmoodAnaam/ok-vqa-ar-en/tree/main)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Clone the Arabic-VQA repository from GitHub.
# !git clone https://github.com/Mahmood-Anaam/Arabic-VQA.git
# Out:
# Cloning into 'Arabic-VQA'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 78 (delta 35), reused 34 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 4.56 MiB | 9.34 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# Install the required libraries from the requirements.txt file.
# !pip install -r /content/Arabic-VQA/requirements.txt --quiet

# %%
# Login to Hugging Face
from huggingface_hub import login
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')
login(token=HF_TOKEN)

# %%
# Load the dataset.
from datasets import load_dataset
dataset = load_dataset("MahmoodAnaam/ok-vqa-ar-en",trust_remote_code=True,cache_dir="/content")
# Out:
# ok-vqa-ar-en.py:   0%|          | 0.00/5.31k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
print(f"Dataset features: \n{dataset}")
# Out:
# Dataset features:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'image_id', 'question_id', 'question', 'question_ar', 'answers', 'question_type', 'answer_type', 'confidence'],
#         num_rows: 9009
#     })
#     validation: Dataset({
#         features: ['image', 'image_id', 'question_id', 'question', 'question_ar', 'answers', 'question_type', 'answer_type', 'confidence'],
#         num_rows: 5046
#     })
# })

# %%
dataset['train'][0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x479>,
#  'image_id': 51606,
#  'question_id': 516065,
#  'question': 'What is the hairstyle of the blond called?',
#  'question_ar': 'ماذا تسمى تسريحة الشعر الاشقر؟',
#  'answers': {'answer': ['pony tail',
#    'pony tail',
#    'pony tail',
#    'pony tail',
#    'pony tail',
#    'pony tail',
#    'braid',
#    'braid',
#    'ponytail',
#    'ponytail'],
#   'answer_ar': ['ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'جديلة',
#    'جديلة',
#    'ذيل حصان',
#    'ذيل حصان'],
#   'raw_answer': ['pony tail',
#    'pony tail',
#    'pony tail',
#    'pony tail',
#    'pony tail',
#    'pony tail',
#    'braid',
#    'braid',
#    'ponytail',
#    'ponytail'],
#   'raw_answer_ar': ['ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'ذيل حصان',
#    'جديلة',
#    'جديلة',
#    'ذيل حصان',
#    'ذيل حصان'],
# ...

# %%
dataset['train'][0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x479>

# %%
dataset['train'][0]['question'],dataset['train'][0]['question_ar']
# Out:
# ('What is the hairstyle of the blond called?',
#  'ماذا تسمى تسريحة الشعر الاشقر؟')

# %%
dataset['train'][0]['answers']
# Out:
# {'answer': ['pony tail',
#   'pony tail',
#   'pony tail',
#   'pony tail',
#   'pony tail',
#   'pony tail',
#   'braid',
#   'braid',
#   'ponytail',
#   'ponytail'],
#  'answer_ar': ['ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'جديلة',
#   'جديلة',
#   'ذيل حصان',
#   'ذيل حصان'],
#  'raw_answer': ['pony tail',
#   'pony tail',
#   'pony tail',
#   'pony tail',
#   'pony tail',
#   'pony tail',
#   'braid',
#   'braid',
#   'ponytail',
#   'ponytail'],
#  'raw_answer_ar': ['ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'ذيل حصان',
#   'جديلة',
#   'جديلة',
#   'ذيل حصان',
#   'ذيل حصان'],
#  'answer_confidence': ['yes',
#   'yes',
#   'yes',
#   'yes',
#   'yes',
#   'yes',
#   'yes',
#   'yes',
#   'yes',
#   'yes']}
